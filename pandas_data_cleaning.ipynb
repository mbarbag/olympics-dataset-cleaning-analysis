# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.2'

# %% [markdown]
# ## About the Dataset
#
# Before cleaning the Olympics Dataset, it's important to understand its origin and structure.
#
# **Data Source:** This data comes from [olympedia.org](https://olympedia.org) and was web scraped by [Keith Galli](https://github.com/KeithGalli).
#
# **Dataset Structure:**
# - `bios.csv`: Contains raw biographical information on each athlete
# - `results.csv`: Contains a row-by-row breakdown of each event athletes competed in and their results
#
# **Coverage:** This repository contains comprehensive data on summer & winter Olympic athletes and their results from 1896-2022.

# %%
# Load the datasets directly from GitHub repository
bios = pd.read_csv('https://github.com/KeithGalli/Olympics-Dataset/raw/refs/heads/master/athletes/bios.csv')
results = pd.read_csv('https://github.com/KeithGalli/Olympics-Dataset/raw/refs/heads/master/results/results.csv')
# Out:
# /var/folders/47/bpf5ysjn14v0z5bjxjd12wzc0000gn/T/ipykernel_5017/4249306157.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   results = pd.read_csv('https://github.com/KeithGalli/Olympics-Dataset/raw/refs/heads/master/results/results.csv')

# %% [markdown]
# ### Use Case
#
# The objective of this analysis is to explore these datasets and extract meaningful insights about Olympic athletes, including:
# - Physical characteristics (height, weight)
# - Geographic origins (birth locations)
# - Career duration and competition patterns
# - Performance across different Olympic games

# %% [markdown]
# ## Dataset Exploration

# %% [markdown]
# ### `bios` Dataset Analysis

# %%
# Examine the structure of raw biographical data
bios.head()
# Out:
#                                        Roles   Sex  \
# 0                  Competed in Olympic Games  Male
# 1                  Competed in Olympic Games  Male
# 2  Competed in Olympic Games • Administrator  Male
# 3                  Competed in Olympic Games  Male
# 4                  Competed in Olympic Games  Male
#
#                                            Full name              Used name  \
# 0  François Joseph Marie Antoine "Jean-François"•...  Jean-François•Blanchy
# 1                            Arnaud Benjamin•Boetsch         Arnaud•Boetsch
# 2                        Jean Laurent Robert•Borotra           Jean•Borotra
# 3               Jacques Marie Stanislas Jean•Brugnon        Jacques•Brugnon
# 4                                 Henry Albert•Canet           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations  \
# 0             NaN                                  NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)
# 2  183 cm / 76 kg                     TCP, Paris (FRA)
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)
# 4             NaN                     TCP, Paris (FRA)
#
#                                 Nick/petnames Title(s) Other names  \
# 0                                         NaN      NaN         NaN
# 1                                         NaN      NaN         NaN
# 2  Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                        Toto      NaN         NaN
# 4                                         NaN      NaN         NaN
#
#   Nationality Original name Name order
# 0         NaN           NaN        NaN
# 1         NaN           NaN        NaN
# 2         NaN           NaN        NaN
# 3         NaN           NaN        NaN
# 4         NaN           NaN        NaN

# %%
# Identify data types, missing values, and memory usage
# This helps plan the cleaning strategy
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Roles          145500 non-null  object
#  1   Sex            145500 non-null  object
#  2   Full name      145500 non-null  object
#  3   Used name      145500 non-null  object
#  4   Born           143772 non-null  object
#  5   Died           34042 non-null   object
#  6   NOC            145499 non-null  object
#  7   athlete_id     145500 non-null  int64
#  8   Measurements   107833 non-null  object
#  9   Affiliations   95832 non-null   object
#  10  Nick/petnames  9145 non-null    object
#  11  Title(s)       399 non-null     object
#  12  Other names    7167 non-null    object
#  13  Nationality    8259 non-null    object
#  14  Original name  30739 non-null   object
#  15  Name order     7844 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 17.8+ MB

# %%
# Find records of people who didn't compete in Olympic Games
# These may need to be filtered out or handled separately
bios.loc[~bios['Roles'].str.contains('Competed in Olympic Games')]
# Out:
#                                                Roles     Sex  \
# 17502                                    Non-starter    Male
# 17518                                    Non-starter    Male
# 17551                                    Non-starter    Male
# 21487                          Non-starter • Referee    Male
# 22192   Competed in Intercalated Games • Non-starter    Male
# ...                                              ...     ...
# 145416                                   Non-starter    Male
# 145443                                   Non-starter  Female
# 145482                                   Non-starter    Male
# 145486                                   Non-starter    Male
# 145499                   Non-starter • Administrator    Male
#
#                                  Full name                    Used name  \
# 17502                  Basil Samuel•Foster                 Basil•Foster
# 17518   Frederick Henry "Freddie"•Browning             Freddie•Browning
# 17551      Edgar Maximilian "Max"•Baerlein                 Max•Baerlein
# 21487      José Luis•Álvarez Gil de Tejada            José Luis•Álvarez
# 22192          Alexandros•Charalampopoulos  Alexandros•Charalampopoulos
# ...                                    ...                          ...
# 145416                           Pat•Nagle                    Pat•Nagle
# 145443                          Eunice•Lee                   Eunice•Lee
# 145482                        Jiang•Dongxu                 Jiang•Dongxu
# 145486                  Dmitry•Karlagachev           Dmitry•Karlagachev
# 145499       William Berge "Bill"•Phillips                Bill•Phillips
#
#                                                      Born  \
# 17502          12 February 1882 in Malvern, England (GBR)
# 17518    1 August 1870 in Bury St. Edmunds, England (GBR)
# 17551       13 December 1879 in Manchester, England (GBR)
# 21487             22 January 1969 in Madrid, Madrid (ESP)
# 22192                                                1883
# ...                                                   ...
# 145416  21 September 1987 in West Bloomfield Township,...
# 145443                        11 November 2004 in ? (KOR)
# 145482         3 March 1993 in Harbin, Heilongjiang (CHN)
# 145486                                    13 October 1998
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                     Died  \
# 17502       28 September 1959 in Uxbridge, England (GBR)
# 17518          13 October 1929 in Flaxley, England (GBR)
# 17551             3 June 1971 in Midhurst, England (GBR)
# 21487                                                NaN
# 22192                                                NaN
# ...                                                  ...
# 145416                                               NaN
# 145443                                               NaN
# 145482                                               NaN
# 145486                                               NaN
# 145499  20 October 2003 in Sydney, New South Wales (AUS)
#
#                                NOC  athlete_id Measurements  \
# 17502                Great Britain       17622          NaN
# 17518                Great Britain       17638          NaN
# 17551                Great Britain       17671          NaN
# 21487                        Spain       21638          NaN
# 22192                       Greece       22357          NaN
# ...                            ...         ...          ...
# 145416               United States      149139          NaN
# 145443               United States      149166          NaN
# 145482  People's Republic of China      149209          NaN
# 145486                         ROC      149213          NaN
# 145499                   Australia      149814          NaN
#
#                                        Affiliations Nick/petnames Title(s)  \
# 17502                                           NaN           NaN      NaN
# 17518                                           NaN           NaN      NaN
# 17551                                           NaN           NaN      NaN
# 21487                                           NaN           NaN      NaN
# 22192   Panhellenios Gymnastikos Syllogos, Heraklis           NaN      NaN
# ...                                             ...           ...      ...
# 145416      Lehigh Valley Phantoms, Allentown (USA)           NaN      NaN
# 145443                                          NaN           NaN      NaN
# 145482                                          NaN           NaN      NaN
# 145486                                          NaN           NaN      NaN
# 145499                                          NaN           NaN      NaN
#
#                         Other names Nationality               Original name  \
# 17502                           NaN         NaN                         NaN
# 17518                           NaN         NaN                         NaN
# 17551                           NaN         NaN                         NaN
# 21487                           NaN         NaN                         NaN
# 22192   Alexandros Charalambopoulos         NaN  Αλέξανδρος•Χαραλαμπόπουλος
# ...                             ...         ...                         ...
# 145416                          NaN         NaN                         NaN
# 145443                          NaN         NaN                         NaN
# 145482                          NaN         NaN                        姜•东旭
# 145486                          NaN         NaN                         NaN
# 145499                          NaN         NaN                         NaN
#
#        Name order
# 17502         NaN
# 17518         NaN
# 17551         NaN
# 21487         NaN
# 22192         NaN
# ...           ...
# 145416        NaN
# 145443        NaN
# 145482   Oriental
# 145486        NaN
# 145499        NaN
#
# [2559 rows x 16 columns]

# %%
# Identify edge cases: people who didn't compete but also didn't fall into excluded categories
# This reveals data quality issues that need special handling
bios.loc[(
    ~bios['Roles'].str.contains('Competed in Olympic Games')) 
    & (~bios['Roles'].str.contains('Non-starter')) 
    & (~bios['Roles'].str.contains('Intercalated Games'))
    & (~bios['Roles'].str.contains('Youth Olympic Games'))
    ]
# Out:
#         Roles     Sex                 Full name        Used name  \
# 137270      —  Female  Jocelyn Margaret•Bartram  Jocelyn•Bartram
# 144949  Other    Male             Dardan•Dehari    Dardan•Dehari
#
#                                           Born Died              NOC  \
# 137270                              4 May 1993  NaN              NaN
# 144949  23 August 1990 in Tetovo, Tetovo (MKD)  NaN  North Macedonia
#
#         athlete_id Measurements Affiliations Nick/petnames Title(s)  \
# 137270      140621          NaN          NaN           NaN      NaN
# 144949      148658          NaN          NaN           NaN      NaN
#
#        Other names Nationality Original name Name order
# 137270         NaN         NaN           NaN        NaN
# 144949         NaN         NaN           NaN        NaN

# %%
# Sample records with titles to understand data patterns
# Helps determine how to handle or preserve this information
bios.loc[bios['Title(s)'].notna()].sample(10)
# Out:
#                                            Roles   Sex  \
# 656                    Competed in Olympic Games  Male
# 17730                  Competed in Olympic Games  Male
# 83742                  Competed in Olympic Games  Male
# 61343                  Competed in Olympic Games  Male
# 12002  Competed in Olympic Games • Administrator  Male
# 17865                  Competed in Olympic Games  Male
# 37128                  Competed in Olympic Games  Male
# 11922                  Competed in Olympic Games  Male
# 21656                  Competed in Olympic Games  Male
# 11780                  Competed in Olympic Games  Male
#
#                                                Full name  \
# 656    Ludwig Albrecht Constantin Maria•von Salm-Hoog...
# 17730              John Graham Hope de la Poer•Beresford
# 83742                 Frederick Arthur Montague•Browning
# 61343                           Riccardo•De Sangro Fondi
# 12002           Gustaf Adolf Oscar Fredrik Arthur Edmund
# 17865                              John "Jack"•Wodehouse
# 37128                             William Lorenzo•Parker
# 11922  Tassilo Wilhelm Humbert Leopold Friedrich Karl...
# 21656                  Ferdinand Marie Ismaël•de Lesseps
# 11780            René Alfred Robert•de Doynel de Quincey
#
#                                 Used name  \
# 656    Ludwig, Graf•von Salm-Hoogstraeten
# 17730                      John•Beresford
# 83742                  Frederick•Browning
# 61343     Riccardo, Conte•De Sangro Fondi
# 12002                  Prins•Gustaf Adolf
# 17865                Jack, Lord•Wodehouse
# 37128                      William•Parker
# 11922   Friedrich Karl, Prinz•von Preußen
# 21656            Ismaël, Comte•de Lesseps
# 11780              René, Comte•de Quincey
#
#                                                     Born  \
# 656    24 February 1885 in Bad Homburg vor der Höhe, ...
# 17730  5 December 1866 in Newcastle upon Tyne, Englan...
# 83742      20 December 1896 in Kensington, England (GBR)
# 61343           22 December 1879 in Napoli, Napoli (ITA)
# 12002        22 April 1906 in Stockholm, Stockholm (SWE)
# 17865          11 November 1883 in Witton, England (GBR)
# 37128  9 January 1889 in South Kensington, England (GBR)
# 11922  6 April 1893 in Klein-Glienicke-Forst, Berlin ...
# 21656       27 November 1871 in Paris VIIIe, Paris (FRA)
# 11780  26 May 1858 in Garcelles-Secqueville, Calvados...
#
#                                                     Died            NOC  \
# 656             23 July 1944 in Budapest, Budapest (HUN)        Austria
# 17730            31 January 1944 in Ascot, England (GBR)  Great Britain
# 83742        14 March 1965 in Tywardreath, England (GBR)  Great Britain
# 61343               11 June 1968 in Napoli, Napoli (ITA)          Italy
# 12002  26 January 1947 in Kastrup Airport, Tårnby, Ho...         Sweden
# 17865        16 April 1941 in Westminster, England (GBR)  Great Britain
# 37128          27 October 1971 in Pontypool, Wales (GBR)  Great Britain
# 11922  6 April 1917 in Saint-Étienne-du-Rouvray, Sein...        Germany
# 21656       30 September 1915 in Vigny, Val-d'Oise (FRA)         France
# 11780            23 August 1924 in Chantilly, Oise (FRA)         France
#
#        athlete_id Measurements                       Affiliations  \
# 656           659          NaN                                NaN
# 17730       17851          NaN       Foxhunters Hurlingham, (GBR)
# 83742       84406          NaN                                NaN
# 61343       61790          NaN             C.R.V.I., Napoli (ITA)
# 12002       12067          NaN             K1 IF, Stockholm (SWE)
# 17865       17986          NaN  The Hurlingham Club, Fulham (GBR)
# 37128       37423          NaN          New College, Oxford (GBR)
# 11922       11987          NaN          Berliner SC, Berlin (GER)
# 21656       21810          NaN                                NaN
# 11780       11842          NaN  Jockey-Club de Paris, Paris (FRA)
#
#       Nick/petnames                                           Title(s)  \
# 656            Ludi                                       Graf (Count)
# 17730           NaN  The Honourable (thru 1910), 5th Baron Decies o...
# 83742           Boy                                                Sir
# 61343           NaN                                      Conte (Count)
# 12002           NaN      Prins (Prince), Hertig (Duke) av Västerbotten
# 17865           NaN                              3rd Earl of Kimberley
# 37128           NaN     Sir, the 3rd Baronet Parker of Shenstone Lodge
# 11922           NaN                         Prinz (Prince) von Preußen
# 21656           NaN                                      Comte (Count)
# 11780           NaN                    Comte (Count) Doynel de Quincey
#
#       Other names Nationality Original name Name order
# 656           NaN         NaN           NaN        NaN
# 17730         NaN         NaN           NaN        NaN
# 83742         NaN         NaN           NaN        NaN
# 61343         NaN         NaN           NaN        NaN
# 12002         NaN         NaN           NaN        NaN
# 17865         NaN     Ireland           NaN        NaN
# 37128         NaN         NaN           NaN        NaN
# 11922         NaN         NaN           NaN        NaN
# 21656         NaN         NaN           NaN        NaN
# 11780         NaN         NaN           NaN        NaN

# %%
# Examine nationality data distribution and format
# Important for deciding data retention strategy
bios.loc[bios['Nationality'].notna()].sample(10)
# Out:
#                                    Roles     Sex                  Full name  \
# 7132           Competed in Olympic Games    Male               Jiří•Šťastný
# 32809  Competed in Olympic Games • Coach    Male            Abas•Arslanagić
# 84822          Competed in Olympic Games    Male               Artur•Endreß
# 28896          Competed in Olympic Games  Female  Hana•Bobková (-Vláčilová)
# 56380          Competed in Olympic Games    Male           Miloslav•Kolařík
# 3593           Competed in Olympic Games    Male     Günther Otto•Heidemann
# 39920          Competed in Olympic Games    Male  Veniamin Yevgenyevich•But
# 86602          Competed in Olympic Games    Male               Rudolf•Höhnl
# 76134          Competed in Olympic Games    Male                Josef•Teplý
# 13600          Competed in Olympic Games    Male              Fridrihs•Bošs
#
#                Used name                                               Born  \
# 7132        Jiří•Šťastný  13 December 1938 in Praha (Prague), Hlavní měs...
# 32809    Abas•Arslanagić            2 October 1944 in Derventa, Doboj (BIH)
# 84822       Artur•Endreß  6 February 1932 in Riessersee, Garmisch-Parten...
# 28896       Hana•Bobková  19 February 1929 in Praha (Prague), Hlavní měs...
# 56380   Miloslav•Kolařík     20 April 1942 in Ludkovice, Zlínský kraj (CZE)
# 3593   Günther•Heidemann            21 October 1932 in Berlin, Berlin (GER)
# 39920       Veniamin•But  1 August 1961 in St. Petersburg, St. Petersbur...
# 86602       Rudolf•Höhnl      21 April 1946 in Lomazice, Ústecký kraj (CZE)
# 76134        Josef•Teplý                                               1902
# 13600      Fridrihs•Bošs        7 February 1887 in Valmiera, Valmiera (LAT)
#
#                                                     Died  \
# 7132                                                 NaN
# 32809                                                NaN
# 84822                                                NaN
# 28896                                               2017
# 56380                                        9 June 1990
# 3593               15 March 2010 in Berlin, Berlin (GER)
# 39920                                                NaN
# 86602                                                NaN
# 76134                                                NaN
# 13600  12 February 1950 in Geesthacht, Schleswig-Hols...
#
#                              NOC  athlete_id    Measurements  \
# 7132              Czechoslovakia        7169  193 cm / 92 kg
# 32809                 Yugoslavia       33055  189 cm / 97 kg
# 84822                    Germany       85500             NaN
# 28896             Czechoslovakia       29110             NaN
# 56380             Czechoslovakia       56781  175 cm / 75 kg
# 3593                     Germany        3605             NaN
# 39920  Soviet Union Unified Team       40228  191 cm / 95 kg
# 86602             Czechoslovakia       87294  158 cm / 71 kg
# 76134             Czechoslovakia       76717             NaN
# 13600         Russian Federation       13683             NaN
#
#                                       Affiliations Nick/petnames Title(s)  \
# 7132                     Slavia Praha, Praha (CZE)           NaN      NaN
# 32809                   RK Borac, Banja Luka (BIH)           NaN      NaN
# 84822  SC Riessersee, Garmisch-Partenkirchen (GER)           NaN      NaN
# 28896                                          NaN           NaN      NaN
# 56380                                          NaN           NaN      NaN
# 3593                   Neuköllner SF, Berlin (GER)           NaN      NaN
# 39920  Dynamo St. Petersburg, St. Petersburg (RUS)           NaN      NaN
# 86602                                          NaN           NaN      NaN
# 76134                SK Pardubice, Pardubice (CZE)           NaN      NaN
# 13600  2. Rīgas Riteņbraucēju biedrība, Rīga (LAT)           NaN      NaN
#
#                         Other names             Nationality  \
# 7132                            NaN                 Czechia
# 32809                           NaN  Bosnia and Herzegovina
# 84822                           NaN            West Germany
# 28896                           NaN                 Czechia
# 56380                           NaN                 Czechia
# 3593                            NaN            West Germany
# 39920                           NaN      Russian Federation
# 86602                           NaN                 Czechia
# 76134                           NaN                 Czechia
# 13600  Friedrich Bosch, Фридрих Бош                  Latvia
#
#                  Original name Name order
# 7132                       NaN        NaN
# 32809          Абас•Арсланагић        NaN
# 84822                      NaN        NaN
# 28896                      NaN        NaN
# 56380                      NaN        NaN
# 3593                       NaN        NaN
# 39920  Вениамин Евгеньевич•Бут        NaN
# 86602                      NaN        NaN
# 76134                      NaN        NaN
# 13600                      NaN        NaN

# %% [markdown]
# ### `results` Dataset Analysis

# %%
# Review the structure of competition results data
# Look for parsing needs and data consistency issues
results.head(15)
# Out:
#                    Games                     Event                   Team  \
# 0   1912 Summer Olympics    Singles, Men (Olympic)                    NaN
# 1   1912 Summer Olympics    Doubles, Men (Olympic)         Jean Montariol
# 2   1920 Summer Olympics    Singles, Men (Olympic)                    NaN
# 3   1920 Summer Olympics  Doubles, Mixed (Olympic)        Jeanne Vaussard
# 4   1920 Summer Olympics    Doubles, Men (Olympic)        Jacques Brugnon
# 5   1996 Summer Olympics    Singles, Men (Olympic)                    NaN
# 6   1996 Summer Olympics    Doubles, Men (Olympic)        Guillaume Raoux
# 7   1924 Summer Olympics    Singles, Men (Olympic)                    NaN
# 8   1924 Summer Olympics  Doubles, Mixed (Olympic)     Marguerite Billout
# 9   1924 Summer Olympics    Doubles, Men (Olympic)           René Lacoste
# 10  1920 Summer Olympics    Singles, Men (Olympic)                    NaN
# 11  1920 Summer Olympics    Doubles, Men (Olympic)  Jean-François Blanchy
# 12  1924 Summer Olympics    Doubles, Men (Olympic)           Henri Cochet
# 13  1912 Summer Olympics    Singles, Men (Olympic)                    NaN
# 14  1912 Summer Olympics  Doubles, Mixed (Olympic)   Marguerite Broquedis
#
#     Pos   Medal                     As  athlete_id  NOC Discipline  \
# 0   =17     NaN  Jean-François Blanchy           1  FRA     Tennis
# 1   DNS     NaN  Jean-François Blanchy           1  FRA     Tennis
# 2   =32     NaN  Jean-François Blanchy           1  FRA     Tennis
# 3    =8     NaN  Jean-François Blanchy           1  FRA     Tennis
# 4     4     NaN  Jean-François Blanchy           1  FRA     Tennis
# 5   =17     NaN         Arnaud Boetsch           2  FRA     Tennis
# 6   =17     NaN         Arnaud Boetsch           2  FRA     Tennis
# 7     4     NaN           Jean Borotra           3  FRA     Tennis
# 8   =15     NaN           Jean Borotra           3  FRA     Tennis
# 9     3  Bronze           Jean Borotra           3  FRA     Tennis
# 10   =9     NaN        Jacques Brugnon           4  FRA     Tennis
# 11    4     NaN        Jacques Brugnon           4  FRA     Tennis
# 12    2  Silver        Jacques Brugnon           4  FRA     Tennis
# 13  =17     NaN           Albert Canet           5  FRA     Tennis
# 14    3  Bronze           Albert Canet           5  FRA     Tennis
#
#    Nationality  Unnamed: 7
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN

# %%
# Assess data quality: types, missing values, structure
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Games        308408 non-null  object
#  1   Event        308408 non-null  object
#  2   Team         121714 non-null  object
#  3   Pos          306583 non-null  object
#  4   Medal        44139 non-null   object
#  5   As           308408 non-null  object
#  6   athlete_id   308408 non-null  int64
#  7   NOC          308407 non-null  object
#  8   Discipline   308407 non-null  object
#  9   Nationality  81 non-null      object
#  10  Unnamed: 7   0 non-null       float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 25.9+ MB

# %%
# Check nationality information in results
# Determine if this duplicates bios data or provides additional value
results.loc[results['Nationality'].notna()]
# Out:
#                        Games                          Event Team  Pos Medal  \
# 5895    1900 Summer Olympics                         Tennis  FRA  NaN   NaN
# 5945    1900 Summer Olympics                           Golf  USA  NaN   NaN
# 15403   1952 Summer Olympics      Canoe Marathon (Canoeing)  GER  NaN   NaN
# 15406   1956 Summer Olympics      Canoe Marathon (Canoeing)  GER  NaN   NaN
# 15457   1956 Summer Olympics      Canoe Marathon (Canoeing)  GER  NaN   NaN
# ...                      ...                            ...  ...  ...   ...
# 208901  1932 Winter Olympics           Ski Jumping (Skiing)  TCH  NaN   NaN
# 208903  1932 Winter Olympics  Cross Country Skiing (Skiing)  TCH  NaN   NaN
# 208908  1936 Winter Olympics       Nordic Combined (Skiing)  TCH  NaN   NaN
# 208911  1948 Winter Olympics       Nordic Combined (Skiing)  TCH  NaN   NaN
# 212272  1960 Winter Olympics  Cross Country Skiing (Skiing)  GER  NaN   NaN
#
#                        As  athlete_id  NOC                     Discipline  \
# 5895        Charles Sands        2786  USA                           Golf
# 5945        Charles Voigt        2796  FRA                         Tennis
# 15403          Egon Drews        9902  GER        Canoe Sprint (Canoeing)
# 15406          Egon Drews        9902  GER        Canoe Sprint (Canoeing)
# 15457     Franz Johannsen        9931  GER        Canoe Sprint (Canoeing)
# ...                   ...         ...  ...                            ...
# 208901  František Šimůnek       97559  TCH       Nordic Combined (Skiing)
# 208903  František Šimůnek       97559  TCH       Nordic Combined (Skiing)
# 208908  František Šimůnek       97559  TCH  Cross Country Skiing (Skiing)
# 208911  František Šimůnek       97559  TCH  Cross Country Skiing (Skiing)
# 212272        Kuno Werner       98904  GER                       Biathlon
#
#        Nationality  Unnamed: 7
# 5895           USA         NaN
# 5945           FRA         NaN
# 15403          FRG         NaN
# 15406          FRG         NaN
# 15457          FRG         NaN
# ...            ...         ...
# 208901         CZE         NaN
# 208903         CZE         NaN
# 208908         CZE         NaN
# 208911         CZE         NaN
# 212272         GDR         NaN
#
# [81 rows x 11 columns]

# %%
# Example of how athlete competition data is structured
# Shows the relationship between bios and results datasets
results.loc[results['athlete_id']==98904]
# Out:
#                        Games                                   Event  \
# 212269  1956 Winter Olympics            15 kilometres, Men (Olympic)
# 212270  1956 Winter Olympics  4 × 10 kilometres Relay, Men (Olympic)
# 212271  1960 Winter Olympics            20 kilometres, Men (Olympic)
# 212272  1960 Winter Olympics           Cross Country Skiing (Skiing)
# 212273  1960 Winter Olympics            15 kilometres, Men (Olympic)
# 212274  1960 Winter Olympics  4 × 10 kilometres Relay, Men (Olympic)
#
#                            Team   Pos Medal           As  athlete_id  NOC  \
# 212269                      NaN  27.0   NaN  Kuno Werner       98904  GER
# 212270  Unified Team of Germany  10.0   NaN  Kuno Werner       98904  GER
# 212271                      NaN   9.0   NaN  Kuno Werner       98904  GER
# 212272                      GER   NaN   NaN  Kuno Werner       98904  GER
# 212273                      NaN  24.0   NaN  Kuno Werner       98904  GER
# 212274  Unified Team of Germany   9.0   NaN  Kuno Werner       98904  GER
#
#                            Discipline Nationality  Unnamed: 7
# 212269  Cross Country Skiing (Skiing)         NaN         NaN
# 212270  Cross Country Skiing (Skiing)         NaN         NaN
# 212271                       Biathlon         NaN         NaN
# 212272                       Biathlon         GDR         NaN
# 212273                       Biathlon         NaN         NaN
# 212274                       Biathlon         NaN         NaN

# %% [markdown]
# ## Data Cleaning Strategy
#
# Based on the exploration above, here's the comprehensive cleaning plan:
#
# ### `bios` Dataset Transformations:
#
# 1. **Birth Information (`Born` column):**
#    - Split into separate columns: `born_date`, `born_city`, `born_region`, `born_country`
#
# 2. **Death Information (`Died` column):**
#    - Extract `died_date` (other death information will be discarded for this use case)
#
# 3. **Name Standardization:**
#    - Use only `Used name` column, rename to `name`
#    - Remove the "•" character separator between first and last names
#    - Drop redundant name columns: `Full name`, `Original name`, `Name order`, `Other names`
#
# 4. **Physical Measurements (`Measurements` column):**
#    - Split into `height_cm` and `weight_kg` columns
#    - Convert to numeric format and standardize units
#
# 5. **Role Classification:**
#    - Filter to include only athletes who "Competed in Olympic Games"
#    - Exclude: Non-starters, Intercalated Games participants, Youth Olympic Games participants
#    - Create `additional_roles` column for competitors with extra responsibilities
#
# 6. **Column Cleanup:**
#    - Drop `Nick/petnames` (high percentage of NaNs, not relevant for analysis)
#
# ### `results` Dataset Transformations:
#
# 1. **Column Cleanup:**
#    - Drop `Unnamed: 7` (empty column)
#    - Drop `Nationality` (will use from `bios` dataset via `athlete_id` join)
#    - Drop `As` column (redundant with `Used name`)
#
# 2. **Data Integration:**
#    - Use `athlete_id` as primary key for joining with cleaned `bios` dataset

# %% [markdown]
# ## Cleaning Bios Data

# %% [markdown]
# ### Establishing `name` column

# %%
# Create a working copy to preserve original data (prevents name binding issues)
bios_new = bios.copy()

# %%
# Remove redundant name-related columns
# Keep only the most commonly used name format
bios_new.drop(columns=['Original name','Name order','Other names','Nick/petnames','Full name'], inplace=True)
bios_new.head()
# Out:
#                                        Roles   Sex              Used name  \
# 0                  Competed in Olympic Games  Male  Jean-François•Blanchy
# 1                  Competed in Olympic Games  Male         Arnaud•Boetsch
# 2  Competed in Olympic Games • Administrator  Male           Jean•Borotra
# 3                  Competed in Olympic Games  Male        Jacques•Brugnon
# 4                  Competed in Olympic Games  Male           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN

# %%
# Standardize column naming convention
bios_new.rename(columns={'Used name': 'name'}, inplace=True)
bios_new.head()
# Out:
#                                        Roles   Sex                   name  \
# 0                  Competed in Olympic Games  Male  Jean-François•Blanchy
# 1                  Competed in Olympic Games  Male         Arnaud•Boetsch
# 2  Competed in Olympic Games • Administrator  Male           Jean•Borotra
# 3                  Competed in Olympic Games  Male        Jacques•Brugnon
# 4                  Competed in Olympic Games  Male           Albert•Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN

# %%
# Replace bullet separator with standard space
# This normalizes name formatting across all records
bios_new['name'] = bios_new['name'].str.replace('•',' ')
bios_new.head()
# Out:
#                                        Roles   Sex                   name  \
# 0                  Competed in Olympic Games  Male  Jean-François Blanchy
# 1                  Competed in Olympic Games  Male         Arnaud Boetsch
# 2  Competed in Olympic Games • Administrator  Male           Jean Borotra
# 3                  Competed in Olympic Games  Male        Jacques Brugnon
# 4                  Competed in Olympic Games  Male           Albert Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN

# %% [markdown]
# ### Filtering Olympic Competitors Based on `Roles` Column

# %%
# Filter to include only athletes who competed in official Olympic Games
# Excludes non-starters, intercalated games, and youth olympics
bios_new = bios_new.loc[bios_new['Roles'].str.contains('Competed in Olympic Games')]
bios_new
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145494                  Competed in Olympic Games    Male
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
#
#                          name  \
# 0       Jean-François Blanchy
# 1              Arnaud Boetsch
# 2                Jean Borotra
# 3             Jacques Brugnon
# 4                Albert Canet
# ...                       ...
# 145494          George Wright
# 145495      Polina Luchnikova
# 145496    Valeriya Merkusheva
# 145497        Yuliya Smirnova
# 145498         André Foussard
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2       13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
# ...                                                   ...
# 145494             21 July 1890 in Toronto, Ontario (CAN)
# 145495         30 January 2002 in Serov, Sverdlovsk (RUS)
# 145496  20 September 1999 in Moskva (Moscow), Moskva (...
# 145497            8 May 1998 in Kotlas, Arkhangelsk (RUS)
# 145498            19 May 1899 in Niort, Deux-Sèvres (FRA)
#
#                                                      Died     NOC  athlete_id  \
# 0       2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                     NaN  France           2
# 2       17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3                   20 March 1978 in Monaco, Monaco (MON)  France           4
# 4                 25 July 1930 in Paris VIIe, Paris (FRA)  France           5
# ...                                                   ...     ...         ...
# 145494   28 January 1973 in Los Angeles, California (USA)  Canada      149221
# 145495                                                NaN     ROC      149222
# 145496                                                NaN     ROC      149223
# 145497                                                NaN     ROC      149224
# 145498          18 March 1986 in Niort, Deux-Sèvres (FRA)  France      149225
#
#           Measurements                                 Affiliations Title(s)  \
# 0                  NaN                                          NaN      NaN
# 1       183 cm / 76 kg           Racing Club de France, Paris (FRA)      NaN
# 2       183 cm / 76 kg                             TCP, Paris (FRA)      NaN
# 3       168 cm / 64 kg          Sporting club de Paris, Paris (FRA)      NaN
# 4                  NaN                             TCP, Paris (FRA)      NaN
# ...                ...                                          ...      ...
# 145494          183 cm          Argonaut Rowing Club, Toronto (CAN)      NaN
# 145495  167 cm / 61 kg                            Agidel, Ufa (RUS)      NaN
# 145496  168 cm / 65 kg  SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)      NaN
# 145497  163 cm / 55 kg                            Agidel, Ufa (RUS)      NaN
# 145498          166 cm                  Beauvoisine FC, Rouen (FRA)      NaN
#
#        Nationality
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 145494         NaN
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498         NaN
#
# [142941 rows x 11 columns]

# %%
# Extract additional roles beyond Olympic competition
# Clean formatting and handle cases with only Olympic competition
bios_new['additional_roles'] = (bios_new['Roles']
    .str.replace('Competed in Olympic Games','')
    .str.replace(r'^\s*•\s*', '', regex=True) # Only remove • at the start
    .replace('',np.nan) # Convert empty strings to NaN
)
bios_new.head()
# Out:
#                                        Roles   Sex                   name  \
# 0                  Competed in Olympic Games  Male  Jean-François Blanchy
# 1                  Competed in Olympic Games  Male         Arnaud Boetsch
# 2  Competed in Olympic Games • Administrator  Male           Jean Borotra
# 3                  Competed in Olympic Games  Male        Jacques Brugnon
# 4                  Competed in Olympic Games  Male           Albert Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality  \
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN
#
#   additional_roles
# 0              NaN
# 1              NaN
# 2    Administrator
# 3              NaN
# 4              NaN

# %%
# Remove original roles column as information is now split appropriately
bios_new.drop(columns='Roles', inplace=True)
bios_new.head()
# Out:
#     Sex                   name  \
# 0  Male  Jean-François Blanchy
# 1  Male         Arnaud Boetsch
# 2  Male           Jean Borotra
# 3  Male        Jacques Brugnon
# 4  Male           Albert Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality  \
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN
#
#   additional_roles
# 0              NaN
# 1              NaN
# 2    Administrator
# 3              NaN
# 4              NaN

# %% [markdown]
# ### Creating `died_date` Column

# %%
# Extract death date from died column
# Split on 'in ' to separate date from location information
bios_new['died_date'] = bios_new['Died'].str.split('in ').str[0]
bios_new.head()
# Out:
#     Sex                   name  \
# 0  Male  Jean-François Blanchy
# 1  Male         Arnaud Boetsch
# 2  Male           Jean Borotra
# 3  Male        Jacques Brugnon
# 4  Male           Albert Canet
#
#                                                 Born  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)
# 1             1 April 1969 in Meulan, Yvelines (FRA)
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)
# 4         17 April 1878 in Wandsworth, England (GBR)
#
#                                                 Died     NOC  athlete_id  \
# 0  2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...  France           1
# 1                                                NaN  France           2
# 2  17 July 1994 in Arbonne, Pyrénées-Atlantiques ...  France           3
# 3              20 March 1978 in Monaco, Monaco (MON)  France           4
# 4            25 July 1930 in Paris VIIe, Paris (FRA)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality  \
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN
#
#   additional_roles        died_date
# 0              NaN  2 October 1960
# 1              NaN              NaN
# 2    Administrator    17 July 1994
# 3              NaN   20 March 1978
# 4              NaN    25 July 1930

# %%
# Validate date extraction format
bios_new.loc[bios_new['died_date'].str.match('1967', na=False)]
# Out:
#           Sex                 name  \
# 170    Female      Lena Valaoritou
# 323      Male        Louis Fierens
# 16814    Male     Ferenc Uhereczky
# 40108    Male    Guillermo Douglas
# 42808    Male       Petrus Visagie
# 46469    Male    Jacques Cartonnet
# 50462    Male      Vasily Karmanov
# 50559    Male      Mikhail Chachba
# 55325    Male          Gus Cummins
# 60427    Male          Bela Juhasz
# 67872    Male      Jérôme Mannaert
# 71439    Male  Giovanni Frangipane
# 71558    Male         Arturo Porro
# 74690    Male           James Doig
# 75193    Male      Olivier Bernard
# 96975    Male           Ion Staicu
#
#                                                     Born  \
# 170        1 March 1897 in Athina (Athens), Attiki (GRE)
# 323           14 October 1875 in Duffel, Antwerpen (BEL)
# 16814             20 January 1898 in Levice, Nitra (SVK)
# 40108        24 October 1909 in Paysandú, Paysandú (URU)
# 42808                                      25 April 1922
# 46469  13 October 1911 in Boulogne-sur-Mer, Pas-de-Ca...
# 50462                                               1927
# 50559                   1930 in Sukhumi, Apkhazeti (GEO)
# 55325            27 October 1886 in Dublin, Dublin (IRL)
# 60427                                               1906
# 67872  22 February 1902 in Beveren, Oost-Vlaanderen (...
# 71439          9 February 1902 in Palermo, Palermo (ITA)
# 71558                       1890 in Milano, Milano (ITA)
# 74690              1894 in Cookhouse, Eastern Cape (RSA)
# 75193                                      26 March 1921
# 96975                                    3 November 1927
#
#                                               Died            NOC  athlete_id  \
# 170                1967 in Ioannina, Epeiros (GRE)         Greece         171
# 323                                           1967        Belgium         324
# 16814               1967 in Bristol, England (GBR)        Hungary       16931
# 40108                                         1967        Uruguay       40416
# 42808  1967 in Kingston-upon-Thames, England (GBR)          Kenya       43133
# 46469                              1967 in ? (ITA)         France       46817
# 50462                                         1967   Soviet Union       50820
# 50559        1967 in Moskva (Moscow), Moskva (RUS)   Soviet Union       50918
# 55325                1967 in London, England (GBR)  Great Britain       55720
# 60427                                         1967     Yugoslavia       60860
# 67872       1967 in Bruay-sur-l'Escaut, Nord (FRA)         France       68386
# 71439                                         1967          Italy       71979
# 71558                 1967 in Milano, Milano (ITA)          Italy       72099
# 74690                      1967 in Transvaal (RSA)   South Africa       75263
# 75193                     1967 in Bern, Bern (SUI)    Switzerland       75770
# 96975                                         1967        Romania       97755
#
#          Measurements                                       Affiliations  \
# 170               NaN                                                NaN
# 323               NaN  Boogschuttersvereniging Willem Tell, Duffel (BEL)
# 16814             NaN                                      Világosság KK
# 40108          193 cm                    Montevideo RC, Montevideo (URU)
# 42808  176 cm / 78 kg                                                NaN
# 46469          168 cm                                  SCUF, Paris (FRA)
# 50462             NaN                                                NaN
# 50559             NaN                                                NaN
# 55325           60 kg                       Limehouse Weightlifting Club
# 60427             NaN                          RK Radnički, Sombor (SRB)
# 67872             NaN                        Stade français, Paris (FRA)
# 71439             NaN                                  US Italia Palermo
# 71558             NaN                                  Sport Club Italia
# 74690             NaN                                 ?, Transvaal (RSA)
# 75193             NaN                                                NaN
# 96975             NaN               CS Metalul I. C. Frimu, Sinaia (ROU)
#
#       Title(s)         Nationality additional_roles died_date
# 170        NaN                 NaN              NaN     1967
# 323        NaN                 NaN              NaN      1967
# 16814      NaN                 NaN              NaN     1967
# 40108      NaN                 NaN              NaN      1967
# 42808      NaN                 NaN              NaN     1967
# 46469      NaN                 NaN              NaN     1967
# 50462      NaN  Russian Federation              NaN      1967
# 50559      NaN  Russian Federation              NaN     1967
# 55325      NaN                 NaN              NaN     1967
# 60427      NaN              Serbia              NaN      1967
# 67872      NaN                 NaN              NaN     1967
# 71439      NaN                 NaN              NaN      1967
# 71558      NaN                 NaN              NaN     1967
# 74690      NaN                 NaN              NaN     1967
# 75193      NaN                 NaN              NaN     1967
# 96975      NaN                 NaN              NaN      1967

# %%
# Check for inconsistent formatting patterns
bios_new.loc[bios_new['died_date'].str.contains('In', na=False)]
# Out:
#         Sex               name                                   Born  \
# 1805   Male       Gharib Afifi  in Al-Qahira (Cairo), Al-Qahira (EGY)
# 39442  Male  Hans Jakob Keller                      18 September 1921
# 49835  Male   Walter Schneider                           13 June 1928
# 52711  Male        Raja Hayder                         31 August 1948
# 54290  Male       Lim Teck Pan                                   1938
#
#                                                   Died          NOC  \
# 1805                                    (In the 1990s)        Egypt
# 39442  (In 2007 or 2008, but before 29 September 2008)  Switzerland
# 49835    (In 2007 or 2008, but before 25 October 2008)  Switzerland
# 52711                            (In or prior to 2004)      Tunisia
# 54290                                   (In the 1970s)    Singapore
#
#        athlete_id    Measurements                            Affiliations  \
# 1805         1812             NaN         El-Olympi, Al-Iskanderiya (EGY)
# 39442       39747             NaN                 RC Zürich, Zürich (SUI)
# 49835       50193             NaN                                     NaN
# 52711       53086  182 cm / 84 kg                   AS Marsa, Marsa (TUN)
# 54290       54680             NaN  Chinese Swimming Club, Singapore (SGP)
#
#       Title(s) Nationality additional_roles  \
# 1805       NaN         NaN              NaN
# 39442      NaN         NaN              NaN
# 49835      NaN         NaN              NaN
# 52711      NaN         NaN              NaN
# 54290      NaN         NaN              NaN
#
#                                              died_date
# 1805                                    (In the 1990s)
# 39442  (In 2007 or 2008, but before 29 September 2008)
# 49835    (In 2007 or 2008, but before 25 October 2008)
# 52711                            (In or prior to 2004)
# 54290                                   (In the 1970s)

# %% [markdown]
# **Note**: Converting `died_date` column to datetime format isn't feasible due to inconsistent date formats throughout the dataset.

# %%
# Remove original died column as relevant information has been extracted
bios_new.drop(columns='Died', inplace=True)
bios_new.head()
# Out:
#     Sex                   name  \
# 0  Male  Jean-François Blanchy
# 1  Male         Arnaud Boetsch
# 2  Male           Jean Borotra
# 3  Male        Jacques Brugnon
# 4  Male           Albert Canet
#
#                                                 Born     NOC  athlete_id  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)  France           1
# 1             1 April 1969 in Meulan, Yvelines (FRA)  France           2
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...  France           3
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)  France           4
# 4         17 April 1878 in Wandsworth, England (GBR)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality  \
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN
#
#   additional_roles        died_date
# 0              NaN  2 October 1960
# 1              NaN              NaN
# 2    Administrator    17 July 1994
# 3              NaN   20 March 1978
# 4              NaN    25 July 1930

# %% [markdown]
# ### Splitting `Born` Column

# %%
# Extract birth date using same pattern as death date
# Split on 'in ' to separate date from location
bios_new['born_date'] = bios_new['Born'].str.split('in ').str[0]
bios_new.head()
# Out:
#     Sex                   name  \
# 0  Male  Jean-François Blanchy
# 1  Male         Arnaud Boetsch
# 2  Male           Jean Borotra
# 3  Male        Jacques Brugnon
# 4  Male           Albert Canet
#
#                                                 Born     NOC  athlete_id  \
# 0        12 December 1886 in Bordeaux, Gironde (FRA)  France           1
# 1             1 April 1969 in Meulan, Yvelines (FRA)  France           2
# 2  13 August 1898 in Biarritz, Pyrénées-Atlantiqu...  France           3
# 3            11 May 1895 in Paris VIIIe, Paris (FRA)  France           4
# 4         17 April 1878 in Wandsworth, England (GBR)  France           5
#
#      Measurements                         Affiliations Title(s) Nationality  \
# 0             NaN                                  NaN      NaN         NaN
# 1  183 cm / 76 kg   Racing Club de France, Paris (FRA)      NaN         NaN
# 2  183 cm / 76 kg                     TCP, Paris (FRA)      NaN         NaN
# 3  168 cm / 64 kg  Sporting club de Paris, Paris (FRA)      NaN         NaN
# 4             NaN                     TCP, Paris (FRA)      NaN         NaN
#
#   additional_roles        died_date          born_date
# 0              NaN  2 October 1960   12 December 1886
# 1              NaN              NaN      1 April 1969
# 2    Administrator    17 July 1994     13 August 1898
# 3              NaN   20 March 1978        11 May 1895
# 4              NaN    25 July 1930      17 April 1878

# %%
# Check for date format variations that prevent datetime conversion
bios_new.loc[bios_new['born_date'].str.contains("c. 1929", regex=False, na=False)]
# Out:
#        Sex             name       Born    NOC  athlete_id Measurements  \
# 1251  Male  Eduardo Cornejo  (c. 1929)  Chile        1258          NaN
#
#      Affiliations Title(s) Nationality additional_roles          died_date  \
# 1251          NaN      NaN         NaN              NaN  23 November 1998
#
#       born_date
# 1251  (c. 1929)

# %% [markdown]
# **Note**: Converting `born_date` column to datetime format isn't feasible due to various date formats including approximate dates (e.g., "c. 1929").

# %%
# Extract country information from parentheses
# Use regex to find content within parentheses, take the last match
bios_new['born_country'] = (bios_new['Born']
    .str.findall(r'\(([^)]+)\)') # Find all text in parentheses
    .str[-1])  # Get last match (in case of multiple parentheses)
bios_new.sample(10)
# Out:
#            Sex                  name  \
# 95948     Male            Jiří Raška
# 35576     Male      Atalibio Magioni
# 23703     Male  Abderrahmane Derouaz
# 142208    Male             Dane Lett
# 61298     Male             John Dawe
# 73203   Female          Gretha Tromp
# 45618     Male            James Hett
# 11929     Male   Karl-Heinz Fuhrmann
# 25843     Male       Gracco De Nardo
# 58643     Male      Katsutoshi Naito
#
#                                                      Born  \
# 95948   4 February 1941 in Frenštát pod Radhoštěm, Mor...
# 35576   25 January 1947 in Venâncio Aires, Rio Grande ...
# 23703   12 December 1955 in Al-Jaza'ir (Algiers), Al-J...
# 142208      29 August 1990 in Masterton, Wellington (NZL)
# 61298                                     14 January 1928
# 73203   21 February 1964 in Heerhugowaard, Noord-Holla...
# 45618           13 April 1958 in Kitchener, Ontario (CAN)
# 11929     18 May 1937 in Recklingen, Sachsen-Anhalt (GER)
# 25843             24 September 1893 in Terni, Terni (ITA)
# 58643        25 February 1895 in Hongawa, Hiroshima (JPN)
#
#                          NOC  athlete_id    Measurements  \
# 95948         Czechoslovakia       96722  165 cm / 70 kg
# 35576                 Brazil       35855  188 cm / 96 kg
# 23703                Algeria       23887  180 cm / 72 kg
# 142208           New Zealand      145809          181 cm
# 61298              Australia       61744  174 cm / 64 kg
# 73203            Netherlands       73765  174 cm / 60 kg
# 45618                 Canada       45963             NaN
# 11929   East Germany Germany       11994  168 cm / 60 kg
# 25843                  Italy       26036             NaN
# 58643                  Japan       59062             NaN
#
#                                           Affiliations Title(s)   Nationality  \
# 95948   Spartak Frenštát, Frenštát pod Radhoštěm (CZE)      NaN       Czechia
# 35576                   Flamengo, Rio de Janeiro (BRA)      NaN           NaN
# 23703                      USM Alger, Al-Jaza'ir (ALG)      NaN           NaN
# 142208                                             NaN      NaN           NaN
# 61298                                              NaN      NaN           NaN
# 73203           Atletiekvereniging Hera, Heerhugowaard      NaN           NaN
# 45618                        CKW YMCA, Kitchener (CAN)      NaN           NaN
# 11929              ASK Vorwärts Potsdam, Potsdam (GER)      NaN  East Germany
# 25843                        SPES Genova, Genova (ITA)      NaN           NaN
# 58643                 Penn Quakers, Philadelphia (USA)      NaN           NaN
#
#        additional_roles           died_date           born_date born_country
# 95948             Other    20 January 2012     4 February 1941           CZE
# 35576               NaN                 NaN    25 January 1947           BRA
# 23703               NaN                 NaN   12 December 1955           ALG
# 142208              NaN                 NaN     29 August 1990           NZL
# 61298               NaN     26 August 2013      14 January 1928          NaN
# 73203               NaN                 NaN   21 February 1964           NED
# 45618               NaN                 NaN      13 April 1958           CAN
# 11929               NaN                 NaN        18 May 1937           GER
# 25843               NaN      22 April 1984   24 September 1893           ITA
# 58643               NaN  27 September 1969    25 February 1895           JPN

# %%
# Extract city name between 'in ' and first comma
bios_new['born_city'] = bios_new['Born'].str.extract(r'in ([^,]+),') # Extract text between 'in ' and first comma
bios_new.sample(10)
# Out:
#            Sex                     name  \
# 19766     Male          David Goldsmith
# 42360     Male           Andreas Vichos
# 20125   Female           Marie Sýkorová
# 77361   Female         Bernice Robinson
# 102058    Male              Kwadwo Poku
# 11063     Male              Steve Lysak
# 4027      Male  Moustafa Mohammed Saleh
# 80398   Female          Monika Feldmann
# 4229      Male              Fujio Nagai
# 30839     Male           Sture Ericsson
#
#                                                      Born             NOC  \
# 19766      27 July 1931 in Christchurch, Canterbury (NZL)     New Zealand
# 42360                                                1877          Greece
# 20125   18 November 1952 in České Budějovice, Jihočesk...  Czechoslovakia
# 77361         28 February 1927 in Chicago, Illinois (USA)   United States
# 102058                5 May 1985 in Kumasi, Western (GHA)           Ghana
# 11063           7 August 1912 in Newark, New Jersey (USA)   United States
# 4027                          3 September 1963 in ? (IRQ)            Iraq
# 80398       5 May 1951 in Frankfurt am Main, Hessen (GER)    West Germany
# 4229           29 September 1951 in Takasaki, Gunma (JPN)           Japan
# 30839             15 January 1898 in Örebro, Örebro (SWE)          Sweden
#
#         athlete_id    Measurements                           Affiliations  \
# 19766        19905             NaN                                    NaN
# 42360        42683             NaN           Panellinios GS, Athina (GRE)
# 20125        20268  160 cm / 50 kg                      Meteor Budejovice
# 77361        77952  178 cm / 71 kg                  Washington Park Dept.
# 102058      102993  178 cm / 80 kg     King Faisal Babes FC, Kumasi (GHA)
# 11063        11122             NaN  Yonkers PRC, Glenwood, New York (USA)
# 4027          4041  170 cm / 54 kg                                    NaN
# 80398        81049  160 cm / 48 kg          FREC, Frankfurt am Main (GER)
# 4229          4243  164 cm / 56 kg                                    NaN
# 30839        31075             NaN              Stockholms GF, Täby (SWE)
#
#        Title(s) Nationality additional_roles           died_date  \
# 19766       NaN         NaN              NaN       25 June 2017
# 42360       NaN         NaN              NaN                 NaN
# 20125       NaN     Czechia              NaN                2018
# 77361       NaN         NaN              NaN     14 October 2019
# 102058      NaN         NaN              NaN                 NaN
# 11063       NaN         NaN              NaN       30 July 2002
# 4027        NaN         NaN              NaN                 NaN
# 80398       NaN         NaN              NaN                 NaN
# 4229        NaN         NaN              NaN   28 September 2007
# 30839       NaN         NaN              NaN  30 September 1945
#
#                  born_date born_country          born_city
# 19766        27 July 1931           NZL       Christchurch
# 42360                 1877          NaN                NaN
# 20125    18 November 1952           CZE   České Budějovice
# 77361    28 February 1927           USA            Chicago
# 102058         5 May 1985           GHA             Kumasi
# 11063       7 August 1912           USA             Newark
# 4027     3 September 1963           IRQ                NaN
# 80398          5 May 1951           GER  Frankfurt am Main
# 4229    29 September 1951           JPN           Takasaki
# 30839     15 January 1898           SWE             Örebro

# %%
# Handle special cases like unknown cities marked with '?'
bios_new.loc[bios_new['Born'] == '7 May 1983 in ? (KOR)']
# Out:
#            Sex           name                   Born                NOC  \
# 112733  Female  Kim Jeong-Hui  7 May 1983 in ? (KOR)  Republic of Korea
#
#         athlete_id    Measurements Affiliations Title(s) Nationality  \
# 112733      114016  165 cm / 57 kg     KT Busan      NaN         NaN
#
#        additional_roles died_date    born_date born_country born_city
# 112733              NaN       NaN  7 May 1983           KOR       NaN

# %%
# Extract region/state information between first comma and parentheses
bios_new['born_region'] = bios_new['Born'].str.extract(r',\s*([^(]+)') #Extract text between first comma and opening parenthesis
bios_new.sample(10)
# Out:
#            Sex               name  \
# 78481     Male           Bob Soth
# 114297    Male     George du Rand
# 63215     Male     Thomas Skinner
# 630       Male        Wally Masur
# 88018     Male  Toshiyuki Kuroiwa
# 88252   Female    Eufemija Štorga
# 40127   Female        Teresa Bell
# 44140     Male        Alp Kızılsu
# 72523     Male  Vilis Cimmermanis
# 71606     Male       Teseo Taddia
#
#                                                      Born            NOC  \
# 78481                    6 April 1933 in Tama, Iowa (USA)  United States
# 114297  16 October 1982 in Bloemfontein, Free State (RSA)   South Africa
# 63215                                                 NaN  Great Britain
# 630             13 May 1963 in Southampton, England (GBR)      Australia
# 88018           27 February 1969 in Tsumagoi, Gunma (JPN)          Japan
# 88252            7 October 1975 in Medvode, Medvode (SLO)       Slovenia
# 40127   28 August 1966 in Washington Crossing, New Jer...  United States
# 44140            17 July 1957 in İstanbul, İstanbul (TUR)        Türkiye
# 72523                29 December 1896 in Rīga, Rīga (LAT)         Latvia
# 71606             20 April 1920 in Bondeno, Ferrara (ITA)          Italy
#
#         athlete_id    Measurements  \
# 78481        79072  173 cm / 61 kg
# 114297      115604  194 cm / 90 kg
# 63215        63685             NaN
# 630            633  180 cm / 76 kg
# 88018        88722  180 cm / 85 kg
# 88252        88958  169 cm / 68 kg
# 40127        40435  178 cm / 59 kg
# 44140        44479  178 cm / 77 kg
# 72523        73075             NaN
# 71606        72148  184 cm / 92 kg
#
#                                        Affiliations Title(s) Nationality  \
# 78481   Southern California Striders, Anaheim (USA)      NaN         NaN
# 114297                                   Free State      NaN         NaN
# 63215                                           NaN      NaN         NaN
# 630                                             NaN      NaN         NaN
# 88018                              Misawa Homes Co.      NaN         NaN
# 88252                      AD Mass, Ljubljana (SLO)      NaN         NaN
# 40127                                           NaN      NaN         NaN
# 44140               Bursa Bueyueksehir Belediyespor      NaN         NaN
# 72523            Rīgās Garnizona Sporta Klubs / LSB      NaN         NaN
# 71606             G.S. Pirelli Milano, Milano (ITA)      NaN         NaN
#
#        additional_roles          died_date          born_date born_country  \
# 78481               NaN                NaN      6 April 1933           USA
# 114297              NaN                NaN   16 October 1982           RSA
# 63215               NaN                NaN                NaN          NaN
# 630                 NaN                NaN       13 May 1963           GBR
# 88018               NaN                NaN  27 February 1969           JPN
# 88252               NaN                NaN    7 October 1975           SLO
# 40127               NaN                NaN    28 August 1966           USA
# 44140               NaN                NaN      17 July 1957           TUR
# 72523               NaN       29 May 1936   29 December 1896           LAT
# 71606               NaN  23 December 1982      20 April 1920           ITA
#
#                   born_city  born_region
# 78481                  Tama        Iowa
# 114297         Bloemfontein  Free State
# 63215                   NaN          NaN
# 630             Southampton     England
# 88018              Tsumagoi       Gunma
# 88252               Medvode     Medvode
# 40127   Washington Crossing  New Jersey
# 44140              İstanbul    İstanbul
# 72523                  Rīga        Rīga
# 71606               Bondeno     Ferrara

# %%
# Remove original born column as information has been properly split
bios_new.drop(columns='Born', inplace=True)
bios_new.head()
# Out:
#     Sex                   name     NOC  athlete_id    Measurements  \
# 0  Male  Jean-François Blanchy  France           1             NaN
# 1  Male         Arnaud Boetsch  France           2  183 cm / 76 kg
# 2  Male           Jean Borotra  France           3  183 cm / 76 kg
# 3  Male        Jacques Brugnon  France           4  168 cm / 64 kg
# 4  Male           Albert Canet  France           5             NaN
#
#                           Affiliations Title(s) Nationality additional_roles  \
# 0                                  NaN      NaN         NaN              NaN
# 1   Racing Club de France, Paris (FRA)      NaN         NaN              NaN
# 2                     TCP, Paris (FRA)      NaN         NaN    Administrator
# 3  Sporting club de Paris, Paris (FRA)      NaN         NaN              NaN
# 4                     TCP, Paris (FRA)      NaN         NaN              NaN
#
#          died_date          born_date born_country    born_city  \
# 0  2 October 1960   12 December 1886           FRA     Bordeaux
# 1              NaN      1 April 1969           FRA       Meulan
# 2    17 July 1994     13 August 1898           FRA     Biarritz
# 3   20 March 1978        11 May 1895           FRA  Paris VIIIe
# 4    25 July 1930      17 April 1878           GBR   Wandsworth
#
#              born_region
# 0               Gironde
# 1              Yvelines
# 2  Pyrénées-Atlantiques
# 3                 Paris
# 4               England

# %% [markdown]
# ### Splitting `Measurements` Column

# %%
# Extract height and weight from measurements string
# Split by ' / ' separator and extract numeric values
bios_new['height_cm'] = bios_new['Measurements'].str.split(' / ').str[0].str.split(' ').str[0]
bios_new['weight_kg'] = bios_new['Measurements'].str.split(' / ').str[1].str.split(' ').str[0]
bios_new.sample(10)
# Out:
#            Sex                  name            NOC  athlete_id  \
# 106840    Male    Giannis Gavrilidis         Greece      107954
# 41639     Male       Sulo Cederström        Finland       41958
# 49349   Female      Gertrudes Lozada    Philippines       49706
# 19413     Male   Mohinder Singh Amar       Malaysia       19551
# 108918    Male            Ted Ligety  United States      110095
# 60835     Male           Will Baylis  United States       61274
# 113336    Male      Bershawn Jackson  United States      114627
# 116487    Male  Jean-Baptiste Bernaz         France      117880
# 18071     Male             Sim Price  United States       18192
# 142488  Female  Yevgeniya Kosetskaya            ROC      146099
#
#           Measurements                                       Affiliations  \
# 106840  176 cm / 74 kg                                    DAS Drapetsonas
# 41639              NaN  Kouvolan Metsästys- ja Ampumaseura, Kouvola (FIN)
# 49349              NaN                                                NaN
# 19413   174 cm / 56 kg                       Jollylads Hockey Sports Club
# 108918  180 cm / 86 kg                Park City Ski Team, Park City (USA)
# 60835   185 cm / 84 kg      The San Francisco Yacht Club, Belvedere (USA)
# 113336  173 cm / 69 kg                              Nike, Beaverton (USA)
# 116487  190 cm / 80 kg  COYCH, Hyères (FRA) / CN Sainte-Maxime, Sainte...
# 18071              NaN            Glen Echo Country Club, St. Louis (USA)
# 142488             NaN                                                NaN
#
#        Title(s) Nationality additional_roles          died_date  \
# 106840      NaN         NaN              NaN                NaN
# 41639       NaN         NaN              NaN      26 June 1944
# 49349       NaN         NaN      Non-starter                NaN
# 19413       NaN         NaN              NaN                NaN
# 108918      NaN         NaN              NaN                NaN
# 60835       NaN         NaN              NaN                NaN
# 113336      NaN         NaN              NaN                NaN
# 116487      NaN         NaN              NaN                NaN
# 18071       NaN         NaN              NaN  16 December 1945
# 142488      NaN         NaN              NaN                NaN
#
#                 born_date born_country           born_city   born_region  \
# 106840   24 January 1982           GRE  Peiraias (Piraeus)       Attiki
# 41639   11 February 1903           FIN             Kouvola  Kymenlaakso
# 49349                1943          NaN                 NaN           NaN
# 19413    15 January 1954           MAS          Alor Setar        Kedah
# 108918    31 August 1984           USA      Salt Lake City         Utah
# 60835      15 April 1962           USA       San Francisco   California
# 113336        8 May 1983           USA               Miami      Florida
# 116487      18 July 1987           FRA              Fréjus          Var
# 18071        16 May 1882           USA           St. Louis     Missouri
# 142488  16 December 1994           RUS         Chelyabinsk  Chelyabinsk
#
#        height_cm weight_kg
# 106840       176        74
# 41639        NaN       NaN
# 49349        NaN       NaN
# 19413        174        56
# 108918       180        86
# 60835        185        84
# 113336       173        69
# 116487       190        80
# 18071        NaN       NaN
# 142488       NaN       NaN

# %%
# Remove original measurements column as data has been split into specific columns
bios_new.drop(columns='Measurements', inplace=True)
bios_new.head()
# Out:
#     Sex                   name     NOC  athlete_id  \
# 0  Male  Jean-François Blanchy  France           1
# 1  Male         Arnaud Boetsch  France           2
# 2  Male           Jean Borotra  France           3
# 3  Male        Jacques Brugnon  France           4
# 4  Male           Albert Canet  France           5
#
#                           Affiliations Title(s) Nationality additional_roles  \
# 0                                  NaN      NaN         NaN              NaN
# 1   Racing Club de France, Paris (FRA)      NaN         NaN              NaN
# 2                     TCP, Paris (FRA)      NaN         NaN    Administrator
# 3  Sporting club de Paris, Paris (FRA)      NaN         NaN              NaN
# 4                     TCP, Paris (FRA)      NaN         NaN              NaN
#
#          died_date          born_date born_country    born_city  \
# 0  2 October 1960   12 December 1886           FRA     Bordeaux
# 1              NaN      1 April 1969           FRA       Meulan
# 2    17 July 1994     13 August 1898           FRA     Biarritz
# 3   20 March 1978        11 May 1895           FRA  Paris VIIIe
# 4    25 July 1930      17 April 1878           GBR   Wandsworth
#
#              born_region height_cm weight_kg
# 0               Gironde        NaN       NaN
# 1              Yvelines        183        76
# 2  Pyrénées-Atlantiques        183        76
# 3                 Paris        168        64
# 4               England        NaN       NaN

# %% [markdown]
# ### Formatting columns

# %%
# Reorder columns for logical data organization
# Group related information together (identity, birth, death, physical, roles)
bios_new = bios_new.loc[:,['athlete_id','Sex','name','born_date','born_city','born_region','born_country','NOC','Nationality','died_date','height_cm','weight_kg','Title(s)','additional_roles','Affiliations']]
bios_new.head()
# Out:
#    athlete_id   Sex                   name          born_date    born_city  \
# 0           1  Male  Jean-François Blanchy  12 December 1886      Bordeaux
# 1           2  Male         Arnaud Boetsch      1 April 1969        Meulan
# 2           3  Male           Jean Borotra    13 August 1898      Biarritz
# 3           4  Male        Jacques Brugnon       11 May 1895   Paris VIIIe
# 4           5  Male           Albert Canet     17 April 1878    Wandsworth
#
#              born_region born_country     NOC Nationality        died_date  \
# 0               Gironde           FRA  France         NaN  2 October 1960
# 1              Yvelines           FRA  France         NaN              NaN
# 2  Pyrénées-Atlantiques           FRA  France         NaN    17 July 1994
# 3                 Paris           FRA  France         NaN   20 March 1978
# 4               England           GBR  France         NaN    25 July 1930
#
#   height_cm weight_kg Title(s) additional_roles  \
# 0       NaN       NaN      NaN              NaN
# 1       183        76      NaN              NaN
# 2       183        76      NaN    Administrator
# 3       168        64      NaN              NaN
# 4       NaN       NaN      NaN              NaN
#
#                           Affiliations
# 0                                  NaN
# 1   Racing Club de France, Paris (FRA)
# 2                     TCP, Paris (FRA)
# 3  Sporting club de Paris, Paris (FRA)
# 4                     TCP, Paris (FRA)

# %%
# Standardize column names to lowercase for consistency
bios_new.rename(columns={'Sex':'sex','Nationality':'nationality','Title(s)':'title(s)','Affiliations':'affiliations'}, inplace=True)
bios_new.head()
# Out:
#    athlete_id   sex                   name          born_date    born_city  \
# 0           1  Male  Jean-François Blanchy  12 December 1886      Bordeaux
# 1           2  Male         Arnaud Boetsch      1 April 1969        Meulan
# 2           3  Male           Jean Borotra    13 August 1898      Biarritz
# 3           4  Male        Jacques Brugnon       11 May 1895   Paris VIIIe
# 4           5  Male           Albert Canet     17 April 1878    Wandsworth
#
#              born_region born_country     NOC nationality        died_date  \
# 0               Gironde           FRA  France         NaN  2 October 1960
# 1              Yvelines           FRA  France         NaN              NaN
# 2  Pyrénées-Atlantiques           FRA  France         NaN    17 July 1994
# 3                 Paris           FRA  France         NaN   20 March 1978
# 4               England           GBR  France         NaN    25 July 1930
#
#   height_cm weight_kg title(s) additional_roles  \
# 0       NaN       NaN      NaN              NaN
# 1       183        76      NaN              NaN
# 2       183        76      NaN    Administrator
# 3       168        64      NaN              NaN
# 4       NaN       NaN      NaN              NaN
#
#                           affiliations
# 0                                  NaN
# 1   Racing Club de France, Paris (FRA)
# 2                     TCP, Paris (FRA)
# 3  Sporting club de Paris, Paris (FRA)
# 4                     TCP, Paris (FRA)

# %%
# Review final dataset structure
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 142941 entries, 0 to 145498
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   athlete_id        142941 non-null  int64
#  1   sex               142941 non-null  object
#  2   name              142941 non-null  object
#  3   born_date         141533 non-null  object
#  4   born_city         118396 non-null  object
#  5   born_region       118396 non-null  object
#  6   born_country      119992 non-null  object
#  7   NOC               142941 non-null  object
#  8   nationality       8237 non-null    object
#  9   died_date         33792 non-null   object
#  10  height_cm         107554 non-null  object
#  11  weight_kg         102800 non-null  object
#  12  title(s)          396 non-null     object
#  13  additional_roles  8328 non-null    object
#  14  affiliations      94221 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 17.4+ MB

# %%
# Check for malformed height entries that contain commas or other formatting issues
# This identifies data quality problems from the original measurements parsing
# Example: "74," indicates incomplete or incorrectly formatted measurement data
bios_new.loc[bios_new['height_cm']=='74,']
# Out:
#        athlete_id   sex             name      born_date          born_city  \
# 37121       37416  Male  Guy O. Nickalls  4 April 1899             Wycombe
# 56003       56400  Male     Jan Smeekens  13 July 1920   Ginneken en Bavel
#
#           born_region born_country            NOC nationality       died_date  \
# 37121        England           GBR  Great Britain         NaN  26 April 1974
# 56003  Noord-Brabant           NED    Netherlands         NaN   23 June 1980
#
#       height_cm weight_kg title(s) additional_roles affiliations
# 37121       74,       NaN      NaN              NaN          NaN
# 56003       74,       NaN      NaN              NaN          NaN

# %%
# Convert height and weight to numeric format for mathematical operations
# errors='coerce' converts invalid/non-numeric values to NaN instead of raising errors
# This handles cases like missing data, text entries, or malformed measurements
bios_new['height_cm'] = pd.to_numeric(bios_new['height_cm'], errors='coerce')
bios_new['weight_kg'] = pd.to_numeric(bios_new['weight_kg'], errors='coerce')
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 142941 entries, 0 to 145498
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   athlete_id        142941 non-null  int64
#  1   sex               142941 non-null  object
#  2   name              142941 non-null  object
#  3   born_date         141533 non-null  object
#  4   born_city         118396 non-null  object
#  5   born_region       118396 non-null  object
#  6   born_country      119992 non-null  object
#  7   NOC               142941 non-null  object
#  8   nationality       8237 non-null    object
#  9   died_date         33792 non-null   object
#  10  height_cm         107483 non-null  float64
#  11  weight_kg         101842 non-null  float64
#  12  title(s)          396 non-null     object
#  13  additional_roles  8328 non-null    object
#  14  affiliations      94221 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 17.4+ MB

# %%
# Export cleaned dataset for future use
bios_new.to_csv('bios_new.csv', index=False)

# %% [markdown]
# ## Cleaning `results` Dataset

# %% [markdown]
# ### Dropping Unnecessary Columns

# %%
# Create working copy to preserve original results data (and avoid name binding issues)
results_new = results.copy()
results_new.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#                       As  athlete_id  NOC Discipline Nationality  Unnamed: 7
# 0  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 1  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 2  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 3  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN
# 4  Jean-François Blanchy           1  FRA     Tennis         NaN         NaN

# %%
# Remove columns that are empty, redundant, or will be sourced from bios dataset
# Unnamed: 7 is completely empty, Nationality will come from bios via athlete_id join
# As column is redundant since name on `bios` dataset exists
results_new.drop(columns=['Unnamed: 7','Nationality','As'], inplace=True)
results_new.head()
# Out:
#                   Games                     Event             Team  Pos Medal  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN  =17   NaN
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol  DNS   NaN
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN  =32   NaN
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard   =8   NaN
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon    4   NaN
#
#    athlete_id  NOC Discipline
# 0           1  FRA     Tennis
# 1           1  FRA     Tennis
# 2           1  FRA     Tennis
# 3           1  FRA     Tennis
# 4           1  FRA     Tennis

# %% [markdown]
# ### Formatting columns

# %%
# Standardize column names to lowercase for consistency with bios dataset
# Improve readability by using more descriptive names where appropriate
results_new.rename(columns = {'Games':'games','Event':'event','Team':'team','Pos':'position','Medal':'medal','Discipline':'discipline'}, inplace=True)
results_new.head()
# Out:
#                   games                     event             team position  \
# 0  1912 Summer Olympics    Singles, Men (Olympic)              NaN      =17
# 1  1912 Summer Olympics    Doubles, Men (Olympic)   Jean Montariol      DNS
# 2  1920 Summer Olympics    Singles, Men (Olympic)              NaN      =32
# 3  1920 Summer Olympics  Doubles, Mixed (Olympic)  Jeanne Vaussard       =8
# 4  1920 Summer Olympics    Doubles, Men (Olympic)  Jacques Brugnon        4
#
#   medal  athlete_id  NOC discipline
# 0   NaN           1  FRA     Tennis
# 1   NaN           1  FRA     Tennis
# 2   NaN           1  FRA     Tennis
# 3   NaN           1  FRA     Tennis
# 4   NaN           1  FRA     Tennis

# %%
# Reorder columns for logical organization
# Place athlete_id first as primary key, followed by competition details
results_new = results_new.loc[:,['athlete_id','NOC','games','event','team','position','medal','discipline']]
results_new.head()
# Out:
#    athlete_id  NOC                 games                     event  \
# 0           1  FRA  1912 Summer Olympics    Singles, Men (Olympic)
# 1           1  FRA  1912 Summer Olympics    Doubles, Men (Olympic)
# 2           1  FRA  1920 Summer Olympics    Singles, Men (Olympic)
# 3           1  FRA  1920 Summer Olympics  Doubles, Mixed (Olympic)
# 4           1  FRA  1920 Summer Olympics    Doubles, Men (Olympic)
#
#               team position medal discipline
# 0              NaN      =17   NaN     Tennis
# 1   Jean Montariol      DNS   NaN     Tennis
# 2              NaN      =32   NaN     Tennis
# 3  Jeanne Vaussard       =8   NaN     Tennis
# 4  Jacques Brugnon        4   NaN     Tennis

# %%
# Export cleaned results dataset for analysis and potential joining with bios data
results_new.to_csv('results_new.csv', index=False)

# %% [markdown]
# ## Exploring the Cleaned Data

# %%
# Analyze gender distribution among Olympic competitors
# This provides baseline demographics for the dataset
bios_new.groupby(bios_new['sex']).count()
# Out:
#         athlete_id    name  born_date  born_city  born_region  born_country  \
# sex
# Female       38236   38236      38198      32614        32614         32925
# Male        104705  104705     103335      85782        85782         87067
#
#            NOC  nationality  died_date  height_cm  weight_kg  title(s)  \
# sex
# Female   38236         1632       2656      31924      30797        42
# Male    104705         6605      31136      75559      71045       354
#
#         additional_roles  affiliations
# sex
# Female              2171         25954
# Male                6157         68267

# %%
# Identify female athletes with official titles or honors
# Explores intersection of gender, achievement, and recognition
bios_female_title = bios_new.loc[(bios_new['sex']=='Female') & (bios_new['title(s)'].notna())].copy()
bios_female_title
# Out:
#         athlete_id     sex                                           name  \
# 61              62  Female                                  Agatha Morton
# 531            533  Female                                 Dorothy Cadman
# 801            805  Female                                  Paola Bologna
# 2400          2410  Female                                   Lilí Álvarez
# 2436          2447  Female                               Élisabeth d'Ayen
# 11270        11329  Female          Patricia Galvin de la Tour d'Auvergne
# 11380        11440  Female                              HRH Princess Anne
# 11431        11491  Female     Fieps, Baroness van Tuyll van Serooskerken
# 11434        11495  Female                                  Ida von Nagel
# 11447        11508  Female                                Lilian Williams
# 17723        17844  Female                           Lucile, Baronne Fain
# 18070        18191  Female                                    Abbie Pratt
# 20518        20663  Female                                Patricia Buller
# 20527        20672  Female                                 Mary Glen-Haig
# 36854        37148  Female                                   Ann Callaway
# 41930        42253  Female                                Pinky le Grelle
# 50695        51054  Female                                  Brenda Helser
# 50866        51225  Female                               Chris von Saltza
# 60480        60913  Female                    Arunee, Princess Bhanubandh
# 60498        60933  Female                   Cristina, Princesa de Borbón
# 60528        60964  Female                                Virginie Hériot
# 60596        61033  Female                                  Beryl Preston
# 61342        61789  Female                  Hélène, Comtesse de Pourtalès
# 64381        64864  Female                         Feodora, Gräfin Schenk
# 68163        68679  Female                                   Kelly Holmes
# 68192        68708  Female                                   Denise Lewis
# 68238        68755  Female                                    Mary Peters
# 72799        73353  Female                                  Mary Rajamani
# 79859        80510  Female                                  Bridget Adams
# 80158        80809  Female                                 Edwina Chamier
# 80277        80928  Female                         Anita de Saint Quentin
# 81480        82132  Female                                    Addie Pryor
# 81637        82289  Female  Gratia, Baroness Schimmelpenninck van der Oye
# 82226        82879  Female                                Diana Tomkinson
# 91828        92558  Female                             Katherine Grainger
# 92987        93734  Female                             Charlene Wittstock
# 100097      100936  Female                           Diana Connolly-Carew
# 102882      103844  Female                             Valerie Adams-Vili
# 115332      116677  Female                 Nathalie til Sayn-Wittgenstein
# 122013      124053  Female                              Laura Trott-Kenny
# 122026      124069  Female                             Jessica Ennis-Hill
# 123854      126097  Female                                Lisa Carrington
#
#                 born_date                born_city          born_region  \
# 61          6 March 1872                  Halstead             England
# 531         16 July 1880                 Lancaster             England
# 801       20 August 1898                    Torino              Torino
# 2400          9 May 1905                      Roma                Roma
# 2436     27 October 1898                 Maintenon        Eure-et-Loir
# 11270      20 March 1939                 Singapore           Singapore
# 11380     15 August 1950               Westminster             England
# 11431        29 May 1964                Marylebone             England
# 11434        15 May 1917                 Beberbeck  Hofgeismar, Hessen
# 11447        9 June 1895                   Trysull    Seisdon, England
# 17723   6 September 1867   La Chapelle-de-Guinchay      Saône-et-Loire
# 18070      21 March 1859                 Cleveland                Ohio
# 20518       13 June 1929                   Horsham             England
# 20527       12 July 1918                 Islington             England
# 36854       8 March 1960                       NaN                  NaN
# 41930         4 May 1952                    Ekeren           Antwerpen
# 50695        26 May 1924             San Francisco          California
# 50866    13 January 1944             San Francisco          California
# 60480   15 September 1930                      NaN                  NaN
# 60498       13 June 1965                    Madrid              Madrid
# 60528       26 July 1890                Le Vésinet            Yvelines
# 60596    2 November 1901                    Ningbo            Zhejiang
# 61342      28 April 1868                  New York            New York
# 64381       5 April 1920               Baruth/Mark         Brandenburg
# 68163      19 April 1970                   Pembury             England
# 68192     27 August 1972             West Bromwich             England
# 68238        6 July 1939                  Halewood             England
# 72799   11 November 1943                     Tapah               Perak
# 79859         4 May 1928                 Hampstead             England
# 80158      27 March 1890                   Chester         Nova Scotia
# 80277   13 November 1901                    Moffat            Scotland
# 81480       1 March 1929                    Barnet             England
# 81637       10 July 1912                     Doorn             Utrecht
# 82226      23 April 1943                    London             England
# 91828   12 November 1975                   Glasgow            Scotland
# 92987    25 January 1978                  Bulawayo            Bulawayo
# 100097      7 April 1940                   Kildare             Kildare
# 102882    6 October 1984                   Rotorua       Bay of Plenty
# 115332        2 May 1975    København (Copenhagen)         Hovedstaden
# 122013     24 April 1992                    Harlow             England
# 122026   28 January 1986                 Sheffield             England
# 123854      23 June 1989                  Tauranga       Bay of Plenty
#
#        born_country            NOC    nationality          died_date  \
# 61              GBR  Great Britain            NaN      5 April 1952
# 531             GBR  Great Britain            NaN  23 December 1971
# 801             ITA          Italy            NaN   13 January 1960
# 2400            ITA          Spain            NaN       8 July 1998
# 2436            FRA         France            NaN   7 December 1969
# 11270           SGP  United States            NaN                NaN
# 11380           GBR  Great Britain            NaN                NaN
# 11431           GBR    Netherlands            NaN                NaN
# 11434           GER        Germany   West Germany    29 August 1971
# 11447           GBR  Great Britain            NaN     14 August 1969
# 17723           FRA         France            NaN   30 January 1942
# 18070           USA         France  United States      26 June 1938
# 20518           GBR  Great Britain            NaN     18 April 2013
# 20527           GBR  Great Britain            NaN   15 November 2014
# 36854           GBR  Great Britain            NaN                NaN
# 41930           BEL  Great Britain            NaN                NaN
# 50695           USA  United States            NaN      26 March 2001
# 50866           USA  United States            NaN                NaN
# 60480           NaN       Thailand            NaN                NaN
# 60498           ESP          Spain            NaN                NaN
# 60528           FRA         France            NaN    28 August 1932
# 60596           CHN  Great Britain            NaN   22 October 1979
# 61342           USA    Switzerland            NaN   2 November 1945
# 64381           GER        Austria            NaN     23 March 2006
# 68163           GBR  Great Britain            NaN                NaN
# 68192           GBR  Great Britain            NaN                NaN
# 68238           GBR  Great Britain            NaN                NaN
# 72799           MAS       Malaysia            NaN                NaN
# 79859           GBR  Great Britain            NaN   18 November 2019
# 80158           CAN         Canada            NaN       31 May 1981
# 80277           GBR         France            NaN                NaN
# 81480           GBR  Great Britain            NaN                NaN
# 81637           NED    Netherlands            NaN  12 February 2012
# 82226           GBR  Great Britain            NaN    30 January 2023
# 91828           GBR  Great Britain            NaN                NaN
# 92987           ZIM   South Africa            NaN                NaN
# 100097          IRL        Ireland            NaN                NaN
# 102882          NZL    New Zealand            NaN                NaN
# 115332          DEN        Denmark            NaN                NaN
# 122013          GBR  Great Britain            NaN                NaN
# 122026          GBR  Great Britain            NaN                NaN
# 123854          NZL    New Zealand            NaN                NaN
#
#         height_cm  weight_kg  \
# 61            NaN        NaN
# 531           NaN        NaN
# 801           NaN        NaN
# 2400          NaN        NaN
# 2436          NaN        NaN
# 11270       165.0       49.0
# 11380       167.0       57.0
# 11431       185.0       62.0
# 11434         NaN        NaN
# 11447       162.0       53.0
# 17723         NaN        NaN
# 18070         NaN        NaN
# 20518         NaN        NaN
# 20527       164.0       68.0
# 36854       182.0       75.0
# 41930       168.0       60.0
# 50695         NaN        NaN
# 50866       178.0       63.0
# 60480         NaN        NaN
# 60498       176.0       65.0
# 60528         NaN        NaN
# 60596         NaN        NaN
# 61342         NaN        NaN
# 64381       176.0       62.0
# 68163       163.0       55.0
# 68192       176.0       68.0
# 68238       173.0       71.0
# 72799       179.0       62.0
# 79859         NaN        NaN
# 80158         NaN        NaN
# 80277       163.0        NaN
# 81480         NaN        NaN
# 81637         NaN        NaN
# 82226       175.0       66.0
# 91828       183.0       78.0
# 92987       177.0       63.0
# 100097      170.0       55.0
# 102882      193.0      120.0
# 115332      176.0       85.0
# 122013      164.0       56.0
# 122026      165.0       57.0
# 123854      168.0       63.0
#
#                                                  title(s) additional_roles  \
# 61                                           Lady Stewart              NaN
# 531                                     Lady Wingate-Saul              NaN
# 801                                  Baronessa (Baroness)              NaN
# 2400                     Condesa (Countess) de la Valdene              NaN
# 2436    Comtesse (Countess) de Noailles et d'Ayen, Lad...              NaN
# 11270                                            Princess              NaN
# 11380                              HRH The Princess Royal    Administrator
# 11431                                            Baroness              NaN
# 11434                                       Freiin (Dame)              NaN
# 11447                                        Lady Hickman              NaN
# 17723                                  Baronne (Baroness)              NaN
# 18070                             Princess Karageorgevich              NaN
# 20518                                        Lady Ashmore              NaN
# 20527                                                Dame    Administrator
# 36854                                       Lady Redgrave              NaN
# 41930                                            Comtesse              NaN
# 50695                      Countess de Morelos y Guerrero              NaN
# 50866                                            Baroness              NaN
# 60480                                            Princess              NaN
# 60498   Su Alteza Real Infanta (Her Royal Highness) Do...            Other
# 60528             Viscountess of Haincque de Saint-Sénoch              NaN
# 60596                                                Lady              NaN
# 61342                                 Comtesse (Countess)              NaN
# 64381   Gräfin (Countess) zu Solms-Baruth, Prinzessin ...              NaN
# 68163                                                Dame            Other
# 68192                                                Dame              NaN
# 68238                                                Dame              NaN
# 72799                                               Datuk              NaN
# 79859                                       Lady Bengough              NaN
# 80158                                        Lady Chamier              NaN
# 80277                                 Comtesse (Countess)              NaN
# 81480                                                Lady              NaN
# 81637                                            Baroness              NaN
# 82226                                     Lady Lewthwaite              NaN
# 91828                                                Dame              NaN
# 92987   Son Altesse Sérénissime la Princesse de Monaco...              NaN
# 100097                                   Baroness Wrangel              NaN
# 102882                                               Dame              NaN
# 115332  Prinsesse (Pricess) Nathalie til Sayn-Wittgens...              NaN
# 122013                                               Dame              NaN
# 122026                                               Dame              NaN
# 123854                                               Dame            Other
#
#                                              affiliations
# 61                                                    NaN
# 531            Lonsdale Archers, Burton in Lonsdale (GBR)
# 801               Circolo del Tennis Torino, Torino (ITA)
# 2400                                                  NaN
# 2436                                                  NaN
# 11270                                 Sweet Briar College
# 11380                                                 NaN
# 11431                                                 NaN
# 11434                                                 NaN
# 11447                                                 NaN
# 17723      Société de sport de Compiègne, Compiègne (FRA)
# 18070                      Dinard Golf Club, Dinard (FRA)
# 20518                   London Fencing Club, London (GBR)
# 20527              Polytechnic Fencing Club, London (GBR)
# 36854                                ULBC, Chiswick (GBR)
# 41930                                                 NaN
# 50695                             LAAC, Los Angeles (USA)
# 50866                   Santa Clara SC, Santa Clara (USA)
# 60480                                                 NaN
# 60498                                                 NaN
# 60528       Cercle de la Voile d'Arcachon, Arcachon (FRA)
# 60596             Bembridge Sailing Club, Bembridge (GBR)
# 61342                                                 NaN
# 64381                                PSV Graz, Graz (AUT)
# 68163   Middlesex Ladies/Ealing, Southall and Middlese...
# 68192               Birchfield Harriers, Birmingham (GBR)
# 68238                               Spartan Ladies, (GBR)
# 72799                 ?, Kuala Lumpur, Kuala Lumpur (MAS)
# 79859                                                 NaN
# 80158                                                 NaN
# 80277                                                 NaN
# 81480                                                 NaN
# 81637                                                 NaN
# 82226                                                 NaN
# 91828                     St. Andrew Boat Club, Edinburgh
# 92987                                            Mustangs
# 100097                                                NaN
# 102882  Counties Manukau / Pakuranga Athletic Club [Au...
# 115332                                                NaN
# 122013  Team Specialized Racing, Fremont (USA) / Matri...
# 122026              City of Sheffield AC, Sheffield (GBR)
# 123854                        Eastern Bay, Whakatane, NZL

# %%
# Cross-reference titled female athletes with their medal achievements
# Determines if formal recognition correlates with Olympic success
bios_female_title_results = pd.merge(left=bios_female_title, right=results_new, how='left', on='athlete_id')

bios_female_title_results.loc[bios_female_title_results['medal'].notna(),['athlete_id','name','born_date','born_country','NOC_x','nationality','NOC_y','title(s)','games','discipline','medal']]
# Out:
#      athlete_id                            name          born_date  \
# 9          2447                Élisabeth d'Ayen   27 October 1898
# 18        11495                   Ida von Nagel       15 May 1917
# 22        18191                     Abbie Pratt     21 March 1859
# 33        51054                   Brenda Helser       26 May 1924
# 34        51225                Chris von Saltza   13 January 1944
# 35        51225                Chris von Saltza   13 January 1944
# 36        51225                Chris von Saltza   13 January 1944
# 37        51225                Chris von Saltza   13 January 1944
# 40        60964                 Virginie Hériot      26 July 1890
# 43        61789   Hélène, Comtesse de Pourtalès     28 April 1868
# 44        61789   Hélène, Comtesse de Pourtalès     28 April 1868
# 48        68679                    Kelly Holmes     19 April 1970
# 50        68679                    Kelly Holmes     19 April 1970
# 51        68679                    Kelly Holmes     19 April 1970
# 53        68708                    Denise Lewis    27 August 1972
# 54        68708                    Denise Lewis    27 August 1972
# 61        68755                     Mary Peters       6 July 1939
# 71        92558              Katherine Grainger  12 November 1975
# 72        92558              Katherine Grainger  12 November 1975
# 73        92558              Katherine Grainger  12 November 1975
# 74        92558              Katherine Grainger  12 November 1975
# 75        92558              Katherine Grainger  12 November 1975
# 81       103844              Valerie Adams-Vili    6 October 1984
# 82       103844              Valerie Adams-Vili    6 October 1984
# 83       103844              Valerie Adams-Vili    6 October 1984
# 84       103844              Valerie Adams-Vili    6 October 1984
# 86       116677  Nathalie til Sayn-Wittgenstein        2 May 1975
# 89       124053               Laura Trott-Kenny     24 April 1992
# 90       124053               Laura Trott-Kenny     24 April 1992
# 91       124053               Laura Trott-Kenny     24 April 1992
# 92       124053               Laura Trott-Kenny     24 April 1992
# 93       124053               Laura Trott-Kenny     24 April 1992
# 94       124053               Laura Trott-Kenny     24 April 1992
# 97       124069              Jessica Ennis-Hill   28 January 1986
# 98       124069              Jessica Ennis-Hill   28 January 1986
# 99       126097                 Lisa Carrington      23 June 1989
# 101      126097                 Lisa Carrington      23 June 1989
# 102      126097                 Lisa Carrington      23 June 1989
# 103      126097                 Lisa Carrington      23 June 1989
# 104      126097                 Lisa Carrington      23 June 1989
# 105      126097                 Lisa Carrington      23 June 1989
#
#     born_country          NOC_x    nationality NOC_y  \
# 9            FRA         France            NaN   FRA
# 18           GER        Germany   West Germany   GER
# 22           USA         France  United States   FRA
# 33           USA  United States            NaN   USA
# 34           USA  United States            NaN   USA
# 35           USA  United States            NaN   USA
# 36           USA  United States            NaN   USA
# 37           USA  United States            NaN   USA
# 40           FRA         France            NaN   FRA
# 43           USA    Switzerland            NaN   SUI
# 44           USA    Switzerland            NaN   SUI
# 48           GBR  Great Britain            NaN   GBR
# 50           GBR  Great Britain            NaN   GBR
# 51           GBR  Great Britain            NaN   GBR
# 53           GBR  Great Britain            NaN   GBR
# 54           GBR  Great Britain            NaN   GBR
# 61           GBR  Great Britain            NaN   GBR
# 71           GBR  Great Britain            NaN   GBR
# 72           GBR  Great Britain            NaN   GBR
# 73           GBR  Great Britain            NaN   GBR
# 74           GBR  Great Britain            NaN   GBR
# 75           GBR  Great Britain            NaN   GBR
# 81           NZL    New Zealand            NaN   NZL
# 82           NZL    New Zealand            NaN   NZL
# 83           NZL    New Zealand            NaN   NZL
# 84           NZL    New Zealand            NaN   NZL
# 86           DEN        Denmark            NaN   DEN
# 89           GBR  Great Britain            NaN   GBR
# 90           GBR  Great Britain            NaN   GBR
# 91           GBR  Great Britain            NaN   GBR
# 92           GBR  Great Britain            NaN   GBR
# 93           GBR  Great Britain            NaN   GBR
# 94           GBR  Great Britain            NaN   GBR
# 97           GBR  Great Britain            NaN   GBR
# 98           GBR  Great Britain            NaN   GBR
# 99           NZL    New Zealand            NaN   NZL
# 101          NZL    New Zealand            NaN   NZL
# 102          NZL    New Zealand            NaN   NZL
# 103          NZL    New Zealand            NaN   NZL
# 104          NZL    New Zealand            NaN   NZL
# 105          NZL    New Zealand            NaN   NZL
#
#                                               title(s)                 games  \
# 9    Comtesse (Countess) de Noailles et d'Ayen, Lad...  1920 Summer Olympics
# 18                                       Freiin (Dame)  1952 Summer Olympics
# 22                             Princess Karageorgevich  1900 Summer Olympics
# 33                      Countess de Morelos y Guerrero  1948 Summer Olympics
# 34                                            Baroness  1960 Summer Olympics
# 35                                            Baroness  1960 Summer Olympics
# 36                                            Baroness  1960 Summer Olympics
# 37                                            Baroness  1960 Summer Olympics
# 40             Viscountess of Haincque de Saint-Sénoch  1928 Summer Olympics
# 43                                 Comtesse (Countess)  1900 Summer Olympics
# 44                                 Comtesse (Countess)  1900 Summer Olympics
# 48                                                Dame  2000 Summer Olympics
# 50                                                Dame  2004 Summer Olympics
# 51                                                Dame  2004 Summer Olympics
# 53                                                Dame  1996 Summer Olympics
# 54                                                Dame  2000 Summer Olympics
# 61                                                Dame  1972 Summer Olympics
# 71                                                Dame  2000 Summer Olympics
# 72                                                Dame  2004 Summer Olympics
# 73                                                Dame  2008 Summer Olympics
# 74                                                Dame  2012 Summer Olympics
# 75                                                Dame  2016 Summer Olympics
# 81                                                Dame  2008 Summer Olympics
# 82                                                Dame  2012 Summer Olympics
# 83                                                Dame  2016 Summer Olympics
# 84                                                Dame  2020 Summer Olympics
# 86   Prinsesse (Pricess) Nathalie til Sayn-Wittgens...  2008 Summer Olympics
# 89                                                Dame  2012 Summer Olympics
# 90                                                Dame  2012 Summer Olympics
# 91                                                Dame  2016 Summer Olympics
# 92                                                Dame  2016 Summer Olympics
# 93                                                Dame  2020 Summer Olympics
# 94                                                Dame  2020 Summer Olympics
# 97                                                Dame  2012 Summer Olympics
# 98                                                Dame  2016 Summer Olympics
# 99                                                Dame  2012 Summer Olympics
# 101                                               Dame  2016 Summer Olympics
# 102                                               Dame  2016 Summer Olympics
# 103                                               Dame  2020 Summer Olympics
# 104                                               Dame  2020 Summer Olympics
# 105                                               Dame  2020 Summer Olympics
#
#                            discipline   medal
# 9                              Tennis  Bronze
# 18   Equestrian Dressage (Equestrian)  Bronze
# 22                               Golf  Bronze
# 33                Swimming (Aquatics)    Gold
# 34                Swimming (Aquatics)  Silver
# 35                Swimming (Aquatics)    Gold
# 36                Swimming (Aquatics)    Gold
# 37                Swimming (Aquatics)    Gold
# 40                            Sailing    Gold
# 43                            Sailing    Gold
# 44                            Sailing  Silver
# 48                          Athletics  Bronze
# 50                          Athletics    Gold
# 51                          Athletics    Gold
# 53                          Athletics  Bronze
# 54                          Athletics    Gold
# 61                          Athletics    Gold
# 71                             Rowing  Silver
# 72                             Rowing  Silver
# 73                             Rowing  Silver
# 74                             Rowing    Gold
# 75                             Rowing  Silver
# 81                          Athletics    Gold
# 82                          Athletics    Gold
# 83                          Athletics  Silver
# 84                          Athletics  Bronze
# 86   Equestrian Dressage (Equestrian)  Bronze
# 89            Cycling Track (Cycling)    Gold
# 90            Cycling Track (Cycling)    Gold
# 91            Cycling Track (Cycling)    Gold
# 92            Cycling Track (Cycling)    Gold
# 93            Cycling Track (Cycling)  Silver
# 94            Cycling Track (Cycling)    Gold
# 97                          Athletics    Gold
# 98                          Athletics  Silver
# 99            Canoe Sprint (Canoeing)    Gold
# 101           Canoe Sprint (Canoeing)    Gold
# 102           Canoe Sprint (Canoeing)  Bronze
# 103           Canoe Sprint (Canoeing)    Gold
# 104           Canoe Sprint (Canoeing)    Gold
# 105           Canoe Sprint (Canoeing)    Gold

# %%
# Investigate athletes who competed for different countries than their birth country
# This reveals patterns of athletic migration and dual citizenship
bios_results = pd.merge(left=bios_new,right=results_new, how='inner',on='athlete_id')

bios_results.loc[
    (bios_results['NOC_y'].notna()) &
    (bios_results['born_country'].notna()) &
    (bios_results['born_country'] != bios_results['NOC_y']),
    ['athlete_id','sex','name','born_date','nationality','born_country','NOC_y','NOC_x','position','discipline']].sample(10)
# Out:
#         athlete_id     sex                   name           born_date  \
# 181132       85674    Male            Josef Fendt     6 October 1947
# 172934       82395  Female      Lidiya Skoblikova       8 March 1939
# 177158       84094    Male             Franz Betz    18 January 1952
# 147916       70818    Male  Alexandros Papafingos               1901
# 137888       66057    Male     Eversleigh Freeman     2 January 1893
# 177481       84206    Male        Liston Bochette       16 June 1957
# 164495       78682    Male           Henry Laskau  12 September 1916
# 73525        31817  Female          Marianna Rácz   17 December 1959
# 103418       47530  Female            Uta Schmuck     19 August 1949
# 95872        44792    Male          Walter Winans       5 April 1852
#
#                nationality born_country NOC_y                 NOC_x  \
# 181132                 NaN          GER   FRG  Germany West Germany
# 172934  Russian Federation          RUS   URS          Soviet Union
# 177158                 NaN          GER   FRG          West Germany
# 147916                 NaN          EGY   GRE                Greece
# 137888                 NaN          JAM   CAN                Canada
# 177481                 NaN          USA   PUR           Puerto Rico
# 164495                 NaN          GER   USA         United States
# 73525                  NaN          HUN   AUT               Austria
# 103418                 NaN          GER   GDR          East Germany
# 95872                  NaN          RUS   USA         United States
#
#           position                     discipline
# 181132         2.0                           Luge
# 172934        11.0        Speed Skating (Skating)
# 177158           7  Cross Country Skiing (Skiing)
# 147916         DNS                      Athletics
# 137888   8 h2 r1/2                      Athletics
# 177481          25          Bobsleigh (Bobsleigh)
# 164495  AC h2 r1/2                      Athletics
# 73525          5.0                       Handball
# 103418         =14            Swimming (Aquatics)
# 95872           29                       Shooting

# %% [markdown]
# ## Data Cleaning Summary
#
# ### Records Impact
# - **Original bios dataset**: 145,500 athletes
# - **After filtering for Olympic competitors**: 142,941 athletes retained
# - **Records removed**: 2,559 athletes (non-starters, intercalated games, youth olympics)
# - **Retention rate**: 98.2%

# %%
print(f"Original bios records: {len(bios):,}")
print(f"Cleaned bios records: {len(bios_new):,}")
print(f"Records removed: {len(bios) - len(bios_new):,}")
print(f"Retention rate: {(len(bios_new)/len(bios)*100):.1f}%")
# Out:
# Original bios records: 145,500
# Cleaned bios records: 142,941
# Records removed: 2,559
# Retention rate: 98.2%

# %% [markdown]
# ### New Columns Created
# **From `bios` dataset:**
# - `name` (standardized from `Used name`)
# - `born_date`, `born_city`, `born_region`, `born_country` (parsed from `Born`)
# - `died_date` (extracted from `Died`)
# - `height_cm`, `weight_kg` (split from `Measurements`)
# - `additional_roles` (extracted non-Olympic roles from `Roles`)
#
# **Column transformations:**
# - Standardized column names to lowercase
# - Removed 5 redundant name columns
# - Removed 3 empty/unnecessary columns from results dataset
#
# ### Data Quality Improvements
# - **Name standardization**: Removed bullet separators (•) for consistent formatting
# - **Role classification**: Clear separation between Olympic competitors and other participants
# - **Geographic parsing**: Structured birth location data into separate, analyzable fields
# - **Physical measurements**: Converted combined measurements into separate numeric-ready columns
# - **Data deduplication**: Removed redundant nationality information between datasets
#
#
# ## Limitations and Considerations
#
# ### Date Parsing Challenges
# - **Inconsistent date formats**: Birth and death dates contain various formats including:
#   - Approximate dates (e.g., "c. 1929")
#   - Incomplete dates (year only, month/year only)
#   - Non-standard date expressions
# - **No datetime conversion**: Due to format inconsistencies, dates remain as strings
# - **Future work**: Custom date parsing functions could standardize more entries
#
# ### Data Quality Issues Identified
# - **Incomplete measurements**: Some height/weight entries contain formatting artifacts (e.g., "74,")
# - **Missing geographic data**: Birth locations sometimes marked as "?" or incomplete
# - **Inconsistent country codes**: Athletes may have different NOC codes between datasets
# - **Special characters**: Original data contains various separators and formatting inconsistencies
#
# ### Assumptions Made During Cleaning
# 1. **Olympic focus**: Excluded non-starters, intercalated games, and youth olympics for analysis consistency
# 2. **Name preference**: Chose `Used name` over `Full name` or `Original name` as primary identifier
# 3. **Role prioritization**: Assumed Olympic competition is primary role, others are additional
# 4. **Geographic hierarchy**: Assumed country (in parentheses) is most reliable location identifier
#
# ### Known Data Limitations
# - **Time period coverage**: Dataset spans 1896-2022, with varying data completeness across eras
# - **Source dependency**: Data quality reflects original olympedia.org content and web scraping accuracy
# - **Missing values**: Significant gaps in biographical information, especially for early Olympic periods
# - **Country representation**: Athletes competing for different countries than birth country may indicate citizenship changes, dual nationality, or historical political changes
#
# ### Recommendations for Further Analysis
# - Implement custom date parsing for better temporal analysis
# - Cross-validate country codes with historical Olympic participation records
# - Consider imputation strategies for missing physical measurements
# - Investigate patterns in cross-country athlete representation
